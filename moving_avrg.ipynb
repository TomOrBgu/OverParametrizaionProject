# %%
temp = """--- Epoch 0 ---
Epoch 0, Classification Discrepancy: 0.8467, JSD: 0.0377,outputs_discrepancy:1.7758533954620361
Epoch 1, Loss: 2.3811
Epoch 1, Loss: 2.3903
--- Epoch 1 ---
Epoch 1, Classification Discrepancy: 0.6772, JSD: 0.0300,outputs_discrepancy:1.141483187675476
Epoch 2, Loss: 2.3138
Epoch 2, Loss: 2.3195
--- Epoch 2 ---
Epoch 2, Classification Discrepancy: 0.6041, JSD: 0.0518,outputs_discrepancy:1.242116093635559
Epoch 3, Loss: 2.2858
Epoch 3, Loss: 2.2904
--- Epoch 3 ---
Epoch 3, Classification Discrepancy: 0.5436, JSD: 0.0690,outputs_discrepancy:1.6509267091751099
Epoch 4, Loss: 2.2684
Epoch 4, Loss: 2.2718
--- Epoch 4 ---
Epoch 4, Classification Discrepancy: 0.4906, JSD: 0.0221,outputs_discrepancy:1.0214271545410156
Epoch 5, Loss: 2.2527
Epoch 5, Loss: 2.2597
--- Epoch 5 ---
Epoch 5, Classification Discrepancy: 0.5524, JSD: 0.0734,outputs_discrepancy:1.46322500705719
Epoch 6, Loss: 2.2467
Epoch 6, Loss: 2.2495
--- Epoch 6 ---
Epoch 6, Classification Discrepancy: 0.4527, JSD: 0.0475,outputs_discrepancy:1.2127513885498047
Epoch 7, Loss: 2.2360
Epoch 7, Loss: 2.2396
--- Epoch 7 ---
Epoch 7, Classification Discrepancy: 0.4304, JSD: 0.0189,outputs_discrepancy:0.9148433208465576
Epoch 8, Loss: 2.2302
Epoch 8, Loss: 2.2327
--- Epoch 8 ---
Epoch 8, Classification Discrepancy: 0.4205, JSD: 0.0227,outputs_discrepancy:0.9272001385688782
Epoch 9, Loss: 2.2260
Epoch 9, Loss: 2.2265
--- Epoch 9 ---
Epoch 9, Classification Discrepancy: 0.4765, JSD: 0.0213,outputs_discrepancy:1.009676218032837
Epoch 10, Loss: 2.2174
Epoch 10, Loss: 2.2199
--- Epoch 10 ---
Epoch 10, Classification Discrepancy: 0.3754, JSD: 0.0181,outputs_discrepancy:0.8924914598464966
Epoch 11, Loss: 2.2120
Epoch 11, Loss: 2.2127
--- Epoch 11 ---
Epoch 11, Classification Discrepancy: 0.4722, JSD: 0.0232,outputs_discrepancy:0.9776548743247986
Epoch 12, Loss: 2.2056
Epoch 12, Loss: 2.2060
--- Epoch 12 ---
Epoch 12, Classification Discrepancy: 0.4584, JSD: 0.0196,outputs_discrepancy:0.9169859290122986
Epoch 13, Loss: 2.2008
Epoch 13, Loss: 2.2019
--- Epoch 13 ---
Epoch 13, Classification Discrepancy: 0.4005, JSD: 0.0161,outputs_discrepancy:0.9503498077392578
Epoch 14, Loss: 2.1972
Epoch 14, Loss: 2.1967
--- Epoch 14 ---
Epoch 14, Classification Discrepancy: 0.4339, JSD: 0.0303,outputs_discrepancy:1.0305712223052979
Epoch 15, Loss: 2.1896
Epoch 15, Loss: 2.1920
--- Epoch 15 ---
Epoch 15, Classification Discrepancy: 0.3897, JSD: 0.0142,outputs_discrepancy:0.8946813941001892
Epoch 16, Loss: 2.1861
Epoch 16, Loss: 2.1871
--- Epoch 16 ---
Epoch 16, Classification Discrepancy: 0.4025, JSD: 0.0182,outputs_discrepancy:0.9743698835372925
Epoch 17, Loss: 2.1834
Epoch 17, Loss: 2.1825
--- Epoch 17 ---
Epoch 17, Classification Discrepancy: 0.3766, JSD: 0.0135,outputs_discrepancy:0.8662969470024109
Epoch 18, Loss: 2.1782
Epoch 18, Loss: 2.1782
--- Epoch 18 ---
Epoch 18, Classification Discrepancy: 0.3761, JSD: 0.0136,outputs_discrepancy:0.8885911703109741
Epoch 19, Loss: 2.1767
Epoch 19, Loss: 2.1753
--- Epoch 19 ---
Epoch 19, Classification Discrepancy: 0.3933, JSD: 0.0212,outputs_discrepancy:1.020490288734436
Epoch 20, Loss: 2.1712
Epoch 20, Loss: 2.1713
--- Epoch 20 ---
Epoch 20, Classification Discrepancy: 0.3987, JSD: 0.0169,outputs_discrepancy:0.9651007056236267
Epoch 21, Loss: 2.1668
Epoch 21, Loss: 2.1695
--- Epoch 21 ---
Epoch 21, Classification Discrepancy: 0.3777, JSD: 0.0170,outputs_discrepancy:0.9661938548088074
Epoch 22, Loss: 2.1654
Epoch 22, Loss: 2.1640
--- Epoch 22 ---
Epoch 22, Classification Discrepancy: 0.4151, JSD: 0.0221,outputs_discrepancy:1.0804699659347534
Epoch 23, Loss: 2.1597
Epoch 23, Loss: 2.1602
--- Epoch 23 ---
Epoch 23, Classification Discrepancy: 0.3836, JSD: 0.0192,outputs_discrepancy:1.0122872591018677
Epoch 24, Loss: 2.1560
Epoch 24, Loss: 2.1568
--- Epoch 24 ---
Epoch 24, Classification Discrepancy: 0.3630, JSD: 0.0197,outputs_discrepancy:0.9920322895050049
Epoch 25, Loss: 2.1521
Epoch 25, Loss: 2.1537
--- Epoch 25 ---
Epoch 25, Classification Discrepancy: 0.3513, JSD: 0.0184,outputs_discrepancy:1.0387325286865234
Epoch 26, Loss: 2.1494
Epoch 26, Loss: 2.1480
--- Epoch 26 ---
Epoch 26, Classification Discrepancy: 0.3936, JSD: 0.0236,outputs_discrepancy:1.1169055700302124
Epoch 27, Loss: 2.1438
Epoch 27, Loss: 2.1460
--- Epoch 27 ---
Epoch 27, Classification Discrepancy: 0.3692, JSD: 0.0191,outputs_discrepancy:1.060896873474121
Epoch 28, Loss: 2.1396
Epoch 28, Loss: 2.1415
--- Epoch 28 ---
Epoch 28, Classification Discrepancy: 0.4031, JSD: 0.0211,outputs_discrepancy:1.121833086013794
Epoch 29, Loss: 2.1347
Epoch 29, Loss: 2.1378
--- Epoch 29 ---
Epoch 29, Classification Discrepancy: 0.4024, JSD: 0.0225,outputs_discrepancy:1.121400237083435
Epoch 30, Loss: 2.1359
Epoch 30, Loss: 2.1330
"""

# %%
import re

# Extract the epoch number, classification discrepancy, JSD, and outputs discrepancy
epoch = re.findall(r'--- Epoch (\d+) ---', temp)
classification_discrepancy = re.findall(r'Classification Discrepancy: ([\d.]+)', temp)
JSD = re.findall(r'JSD: ([\d.]+)', temp)
outputs_discrepancy = re.findall(r'outputs_discrepancy:([\d.]+)', temp)

# Plot moving average of classification discrepancy, JSD, and outputs discrepancy
import matplotlib.pyplot as plt
import numpy as np

def moving_average(a, n=3) :
    ret = np.cumsum(a, dtype=float)
    ret[n:] = ret[n:] - ret[:-n]
    return ret[n - 1:] / n

# %%
# Plot moving average of classification discrepancy
plt.plot(moving_average([float(i) for i in classification_discrepancy], n=3), label='classification discrepancy')
plt.xlabel('Epoch')
plt.ylabel('Moving Average')
# Out:
# Text(0, 0.5, 'Moving Average')

# %%
# Plot moving average of classification discrepancy
plt.plot(moving_average([float(i) for i in JSD], n=4), label='jsp discrepancy')
plt.xlabel('Epoch')
plt.ylabel('Moving Average')
# Out:
# Text(0, 0.5, 'Moving Average')
